# %%
# %%html
# ---
#
# <p style='text-align: center;'> THE SPARKS FOUNDATION</p>
# <h1 align="center">Decision Tree on Iris Dataset</h1>
# <div style="text-align: right">created<br>
# -- by Oussama Mahmoudi<br>
# -- for The Sparks Foundation</div>
#
# ---
# Out:
# ---
#
# <p style='text-align: center;'> THE SPARKS FOUNDATION</p>
# <h1 align="center">Decision Tree on Iris Dataset</h1>
# <div style="text-align: right">created<br>
# -- by Oussama Mahmoudi<br>
# -- for The Sparks Foundation</div>
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
# %matplotlib inline

# %%
data = pd.read_csv("Iris.csv")

# %%
data.head()
data.set_index("Id",inplace=True)

# %%
X = data.iloc[:,0:4]
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1              5.1           3.5            1.4           0.2
# 2              4.9           3.0            1.4           0.2
# 3              4.7           3.2            1.3           0.2
# 4              4.6           3.1            1.5           0.2
# 5              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 146            6.7           3.0            5.2           2.3
# 147            6.3           2.5            5.0           1.9
# 148            6.5           3.0            5.2           2.0
# 149            6.2           3.4            5.4           2.3
# 150            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y = data.iloc[:,4]
y
# Out:
# Id
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
#             ...
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# 150    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
dtree=DecisionTreeClassifier()
dtree.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
fig = plt.figure(figsize=(25,20))
detree =tree.plot_tree(dtree,
                   feature_names=dtree.feature_names_in_,  
                   class_names=dtree.classes_,
                   filled=True)
